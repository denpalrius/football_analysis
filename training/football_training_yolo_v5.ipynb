# %% [markdown]
# ### Use Yolo v5 to train a model that better recognizes the ball, players and referees

# %%
! pip install -U ultralytics --quiet
! pip install roboflow --quiet
! pip install ipython-secrets --quiet

# %%
from ipython_secrets import *

ROBOFLOW_API_KEY = get_secret('ROBOFLOW_API_KEY')

# %% [markdown]
# Acquire the dataset

# %%
from roboflow import Roboflow

RF_WORKSPACE = "roboflow-jvuqo"
RF_PROJECT = "football-players-detection-3zvbc"
RF_YOLO_VERSION = "yolov5"

rf = Roboflow(api_key=ROBOFLOW_API_KEY)

project = rf.workspace(RF_WORKSPACE).project(RF_PROJECT)
version = project.version(8)

dataset = version.download(RF_YOLO_VERSION)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil

shutil.move('football-players-detection-8/train',
            'football-players-detection-8/football-players-detection-8/train')

shutil.move('football-players-detection-8/valid',
            'football-players-detection-8/football-players-detection-8/valid')

shutil.move('football-players-detection-8/test',
            'football-players-detection-8/football-players-detection-8/test')
# Out:
# 'football-players-detection-8/football-players-detection-8/test'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5lu.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch=16
# Out:
# New https://pypi.org/project/ultralytics/8.2.3 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.45 🚀 Python-3.11.5 torch-2.2.2 CPU (Apple M1 Pro)
# engine/trainer: task=detect, mode=train, model=yolov5lu.pt, data=/Users/mzitoh/Desktop/USD-Source/YOLO/football_analysis/training/football-players-detection-8/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      7040  ultralytics.nn.modules.conv.Conv             [3, 64, 6, 2, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   1118208  ultralytics.nn.modules.block.C3              [256, 256, 6]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  9   6433792  ultralytics.nn.modules.block.C3              [512, 512, 9]
#   7                  -1  1   4720640  ultralytics.nn.modules.conv.Conv             [512, 1024, 3, 2]
#   8                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3]
#   9                  -1  1   2624512  ultralytics.nn.modules.block.SPPF            [1024, 1024, 5]
#  10                  -1  1    525312  ultralytics.nn.modules.conv.Conv             [1024, 512, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2757632  ultralytics.nn.modules.block.C3              [1024, 512, 3, False]
#  14                  -1  1    131584  ultralytics.nn.modules.conv.Conv             [512, 256, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  3    690688  ultralytics.nn.modules.block.C3              [512, 256, 3, False]
#  18                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  3   2495488  ultralytics.nn.modules.block.C3              [512, 512, 3, False]
#  21                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  3   9971712  ultralytics.nn.modules.block.C3              [1024, 1024, 3, False]
#  24        [17, 20, 23]  1   7060444  ultralytics.nn.modules.head.Detect           [4, [256, 512, 1024]]
# YOLOv5l summary: 416 layers, 53166428 parameters, 53166412 gradients, 135.3 GFLOPs
#
# Transferred 685/691 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.24.dfl.conv.weight'
# train: Scanning /Users/mzitoh/Desktop/USD-Source/YOLO/football_analysis/training
# val: Scanning /Users/mzitoh/Desktop/USD-Source/YOLO/football_analysis/training/f
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.224      1.864     0.8459        458        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.43      0.296      0.273      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.084     0.8802     0.8151        473        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.598      0.355      0.333      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G      1.162      0.791     0.8083        467        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.37      0.528      0.349      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G       1.22     0.7604     0.8152        495        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.828      0.407      0.513      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G       1.27     0.7998     0.8195        402        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.77      0.523      0.577      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G        1.3     0.9019     0.8259        591        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.488      0.483      0.303      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G      1.248     0.7227     0.8233        487        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.355      0.499      0.197      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G      1.266      0.682     0.8237        603        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.457      0.538      0.307      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G      1.273     0.6752     0.8189        437        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.668      0.488      0.418      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G      1.333     0.7049     0.8269        453        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.626      0.316       0.39      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G      1.218     0.6576     0.8212        482        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.796      0.474      0.561      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G      1.173     0.6057     0.8134        528        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.752      0.631      0.632      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G      1.119     0.5848     0.8071        564        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.754      0.675      0.688      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G      1.122     0.5955     0.8103        393        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.823      0.678      0.715      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100         0G      1.119     0.5928     0.8012        592        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.729      0.663      0.693      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         0G      1.145     0.6137     0.8121        594        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.639      0.592       0.52       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         0G      1.133     0.6024     0.8127        504        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.674      0.647      0.597      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         0G      1.086     0.5862      0.808        397        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.807       0.65      0.702      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         0G      1.076     0.5913     0.8041        449        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.836      0.611      0.674      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         0G       1.08     0.6212     0.8105        415        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.775      0.587      0.669      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100         0G      1.187     0.6477       0.81        621        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.659      0.581      0.637      0.375
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100         0G      1.121     0.5886     0.7999        582        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.87      0.585       0.71      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100         0G      1.046     0.5448     0.8029        408        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.835      0.668      0.741      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100         0G      1.071     0.5387     0.8023        553        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.875      0.585      0.693      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100         0G       1.05     0.5208     0.8004        417        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.853      0.634      0.736      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         0G          1     0.5053     0.8011        497        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.856      0.665      0.732      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100         0G          1     0.5013     0.8003        673        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.75      0.666      0.727       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100         0G     0.9783     0.4956     0.7984        562        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.798      0.714      0.769      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         0G     0.9908     0.5123     0.8005        481        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.616       0.53      0.553      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100         0G      1.009     0.5269     0.7919        603        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.81      0.633      0.719      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100         0G     0.9953     0.5033     0.7963        427        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.909      0.677      0.781      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100         0G      1.006      0.511     0.7966        448        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.903      0.656      0.762        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100         0G     0.9635     0.4937     0.7952        510        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.825      0.638      0.732      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100         0G     0.9728     0.4938     0.7966        456        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.847      0.622      0.714      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100         0G     0.8935     0.4729     0.7945        488        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.879      0.637      0.731      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100         0G     0.9411     0.4811     0.7962        459        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.835      0.686      0.749      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100         0G     0.9714     0.4849     0.7964        411        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.82      0.637      0.715      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100         0G     0.9372     0.4607     0.7931        526        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.791      0.697      0.733      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100         0G     0.9424     0.4657     0.7961        395        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.872      0.622      0.703      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100         0G     0.9291     0.4615     0.7934        464        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.823      0.651      0.723      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100         0G     0.9061     0.4522     0.7931        487        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.847       0.69      0.745      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100         0G     0.9278     0.4588     0.7929        571        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.862      0.658      0.728      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100         0G      0.948     0.4677     0.7949        498        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.89      0.661      0.731      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100         0G     0.9182     0.4658     0.7924        531        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.88      0.709      0.771      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100         0G     0.9286     0.4584     0.7925        494        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.912      0.706       0.76      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100         0G     0.9283      0.454      0.792        352        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.911      0.706      0.778      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100         0G     0.8965     0.4449     0.7902        411        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.899      0.687      0.761      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100         0G     0.9183     0.4441     0.7891        526        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.906      0.702      0.782      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100         0G     0.8703     0.4293     0.7883        446        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.882      0.679      0.761      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100         0G     0.8783     0.4233     0.7896        621        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.915      0.719       0.78      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100         0G     0.8822      0.427      0.789        426        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.878      0.743      0.776      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100         0G     0.8881     0.4377     0.7885        458        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.843      0.708      0.757      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100         0G     0.8816     0.4288     0.7902        469        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.891       0.72       0.78      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100         0G     0.8638     0.4131     0.7893        488        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.912      0.735      0.781      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100         0G     0.8873     0.4258      0.786        439        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.885      0.722      0.773      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100         0G     0.8969     0.4299     0.7887        485        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.851      0.748      0.781      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100         0G      0.881     0.4164     0.7877        469        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.85      0.718      0.766      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100         0G     0.8575     0.4109     0.7806        577        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.834      0.695      0.753      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100         0G     0.8467     0.4032      0.787        561        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.913      0.742      0.779      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100         0G     0.8426     0.4066     0.7893        594        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.906      0.725      0.779      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100         0G     0.8533     0.4084     0.7862        415        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.918      0.725      0.786       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100         0G     0.8752     0.4073     0.7819        526        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.835      0.716       0.77      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100         0G     0.8578     0.4025      0.787        634        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.914       0.68      0.762      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100         0G     0.8344     0.3915     0.7857        430        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.945      0.717      0.794      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100         0G     0.8283     0.3944     0.7843        541        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.857      0.731       0.78      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100         0G     0.8486     0.3919     0.7892        531        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.915      0.702      0.775      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100         0G     0.8243     0.3876     0.7842        619        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.827      0.722      0.785       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100         0G     0.7985     0.3836     0.7851        460        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.881       0.74      0.784       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100         0G     0.8445     0.3926     0.7834        510        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.893      0.711       0.78      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100         0G     0.8109     0.3831     0.7824        416        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.904      0.675      0.763      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100         0G     0.8063     0.3781     0.7816        483        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.887      0.706      0.782      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100         0G     0.8103     0.3705     0.7836        506        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.892      0.731        0.8      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100         0G     0.8172      0.382     0.7836        508        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.889      0.723      0.792      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100         0G      0.809     0.3813     0.7804        486        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.946       0.73      0.795      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100         0G     0.7919     0.3709      0.785        400        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.909      0.759        0.8      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100         0G      0.814     0.3793     0.7835        477        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.865      0.764      0.807      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100         0G     0.8038     0.3771     0.7821        544        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.855       0.74      0.799      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100         0G     0.7979     0.3733     0.7823        400        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.91      0.737      0.778      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100         0G     0.7776     0.3734     0.7841        484        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905        0.9      0.747       0.79      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100         0G     0.8121     0.3827     0.7812        438        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.884      0.762      0.807       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100         0G     0.7798     0.3679     0.7802        535        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.891      0.762      0.809      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100         0G       0.77     0.3631     0.7784        510        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.929      0.729      0.803      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100         0G     0.7764     0.3624     0.7845        524        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.931      0.727      0.804      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100         0G     0.7662     0.3592      0.781        511        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905       0.91      0.723      0.806      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100         0G     0.8058     0.3682     0.7828        510        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.877      0.779       0.81      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100         0G     0.7545      0.356     0.7859        430        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.941      0.751      0.805      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100         0G     0.7755     0.3603     0.7807        436        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.933      0.736      0.812      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100         0G     0.7789     0.3626     0.7829        511        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905        0.9      0.724      0.798      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100         0G     0.7418      0.349     0.7796        452        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.902      0.713      0.791      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100         0G     0.7784     0.3592     0.7799        556        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.897      0.715      0.805      0.569
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100         0G     0.7246     0.3549     0.7804        274        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.891      0.744      0.797      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100         0G     0.7172     0.3451     0.7793        278        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.899      0.765      0.803      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100         0G     0.7015      0.332     0.7818        276        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.877      0.755      0.807      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100         0G     0.7173     0.3409     0.7788        275        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.862       0.75      0.806      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100         0G     0.7137     0.3384     0.7801        287        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.861      0.732      0.808      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100         0G     0.6888     0.3296     0.7852        271        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.919      0.747        0.8      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100         0G     0.6885     0.3299     0.7817        278        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.954      0.718      0.808      0.583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100         0G     0.6669     0.3217     0.7796        280        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.923       0.73      0.805      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100         0G     0.6848     0.3231     0.7763        282        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.929      0.711      0.792      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         0G     0.6809      0.321     0.7821        276        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.953      0.699      0.791      0.569
#
# 100 epochs completed in 16.385 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 106.8MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 106.8MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics YOLOv8.1.45 🚀 Python-3.11.5 torch-2.2.2 CPU (Apple M1 Pro)
# YOLOv5l summary (fused): 303 layers, 53134492 parameters, 0 gradients, 134.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         38        905      0.862       0.75      0.806      0.588
#                   ball         38         35      0.804        0.2      0.324      0.126
#             goalkeeper         38         27      0.878      0.926      0.972      0.781
#                 player         38        754      0.935      0.964      0.985      0.796
#                referee         38         89      0.831       0.91      0.943      0.649
# Speed: 0.9ms preprocess, 540.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train
